# %%
# !python3 predict4.py --weights yolov5l-seg.pt --img 640 --conf 0.35 --source /home/selectstar/yolov5/datasets/coco8-pose/images/test --save-txt
# Out:
# segment/predict4: weights=['yolov5m-seg.pt'], source=/home/selectstar/yolov5/datasets/coco8-pose/images/test, data=../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-335-g40f490d9 Python-3.10.13 torch-2.1.0+cu118 CUDA:0 (NVIDIA RTX A5000, 24256MiB)
#
# Fusing layers...
# YOLOv5m-seg summary: 301 layers, 21971597 parameters, 0 gradients, 70.8 GFLOPs
# Image height: 275, y_min: 190.78125655651093, y_max: 219.140625, height: 28.359368443489075
# image condition: 137.5, person height: 28.359368443489075
# ...
